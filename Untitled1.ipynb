# %%
import pandas as pd

# %%
import urllib.request

# %%
urllib.request.urlretrieve('http://nbviewer.jupyter.org/github/maskot1977/Statistics2017/blob/master/fscore.txt', 'fscore.txt')
# Out:
# ('fscore.txt', <http.client.HTTPMessage at 0x10707b198>)

# %%
df = pd.read_csv('fscore.txt', sep="\t")

# %%
df
# Out:
#     case  factor1  factor2  factor3  factor4
# 0      1 -1.23449  1.65060 -0.93305 -1.64936
# 1      2 -0.91006 -0.10156 -0.66936  1.20829
# 2      3  0.32236  0.76397  0.60578 -1.12031
# 3      4  1.50145  0.84835 -0.57517  0.26384
# 4      5  0.34458 -1.68209 -0.61888 -0.44992
# 5      6  0.41702 -1.64413 -0.06561 -0.46898
# 6      7  0.65159  1.17954 -1.05121 -0.71660
# 7      8 -0.17800 -0.37212  1.70362  1.23919
# 8      9  1.30898 -0.12618 -0.29320  1.03229
# 9     10  1.00224  1.09957 -0.24233 -0.89368
# 10    11 -0.71732  0.46452  1.11258  0.79510
# 11    12  0.61664 -1.62513 -0.72810 -0.21379
# 12    13 -0.38022 -0.43818 -0.75633  0.84542
# 13    14 -0.91610  0.20400 -0.75669  0.68478
# 14    15  0.61187 -1.84551  0.11135 -0.20639
# 15    16 -0.21108 -0.64234  2.34029  0.08542
# 16    17  0.08528 -0.02356  0.51231 -0.63368
# 17    18  0.65477 -1.06308  0.61925 -0.28927
# 18    19  0.20644 -0.81055 -0.12123  0.68574
# 19    20 -0.65982  0.11795  0.40679  0.86007
# ...

# %%
df_women = df.iloc[:40, :]

# %%
df_men = df.iloc[40:, :]

# %%
df_men.mean()
# Out:
# case       60.500000
# factor1     0.160878
# factor2    -0.034183
# factor3     0.185733
# factor4    -0.101128
# dtype: float64
