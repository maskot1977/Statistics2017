# %%
import urllib.request # Python 3 の場合

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

# %%
urllib.request.urlretrieve(url, 'winequality-red.csv') # Python 3 の場合
# Out:
# ('winequality-red.csv', <http.client.HTTPMessage at 0x104801828>)

# %%
import pandas as pd
df1 = pd.read_csv('winequality-red.csv', sep=';') 
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df1.to_csv('winequality-red.txt', sep="\t")

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# %%
urllib.request.urlretrieve(url, 'winequality-white.csv') # Python 3 の場合
# Out:
# ('winequality-white.csv', <http.client.HTTPMessage at 0x108a2c0f0>)

# %%
import pandas as pd
df1 = pd.read_csv('winequality-white.csv', sep=';') 
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
df1.to_csv('winequality-white.txt', sep="\t")

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data'

# %%
urllib.request.urlretrieve(url, 'abalone.data') # Python 3 の場合
# Out:
# ('abalone.data', <http.client.HTTPMessage at 0x108a3e5c0>)

# %%
import pandas as pd
df1 = pd.read_csv('abalone.data', sep=',', header=None) 
df1
# Out:
#       0      1      2      3       4       5       6       7   8
# 0     M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  15
# 1     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 2     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 3     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 4     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 5     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# 6     F  0.530  0.415  0.150  0.7775  0.2370  0.1415  0.3300  20
# 7     F  0.545  0.425  0.125  0.7680  0.2940  0.1495  0.2600  16
# 8     M  0.475  0.370  0.125  0.5095  0.2165  0.1125  0.1650   9
# 9     F  0.550  0.440  0.150  0.8945  0.3145  0.1510  0.3200  19
# 10    F  0.525  0.380  0.140  0.6065  0.1940  0.1475  0.2100  14
# 11    M  0.430  0.350  0.110  0.4060  0.1675  0.0810  0.1350  10
# 12    M  0.490  0.380  0.135  0.5415  0.2175  0.0950  0.1900  11
# ...

# %%
df1.to_csv('abalone.txt', sep="\t")

# %%
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/pima-indians-diabetes.txt'

# %%
urllib.request.urlretrieve(url, 'pima-indians-diabetes.data') # Python 3 の場合
# Out:
# ('pima-indians-diabetes.data', <http.client.HTTPMessage at 0x108a34390>)

# %%
import pandas as pd
df1 = pd.read_csv('pima-indians-diabetes.data', sep=',') 
df1
# Out:
#      NumTimePreg  OralGluTol  BloodPres  SkinThick  SerumInsulin   BMI  \
# 0              6         148         72         35             0  33.6
# 1              1          85         66         29             0  26.6
# 2              8         183         64          0             0  23.3
# 3              1          89         66         23            94  28.1
# 4              0         137         40         35           168  43.1
# 5              5         116         74          0             0  25.6
# 6              3          78         50         32            88  31.0
# 7             10         115          0          0             0  35.3
# 8              2         197         70         45           543  30.5
# 9              8         125         96          0             0   0.0
# 10             4         110         92          0             0  37.6
# 11            10         168         74          0             0  38.0
# ...

# %%
df1.to_csv('pima-indians-diabetes.txt', sep="\t")

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data'

# %%
urllib.request.urlretrieve(url, 'parkinsons.data') # Python 3 の場合
# Out:
# ('parkinsons.data', <http.client.HTTPMessage at 0x10918c860>)

# %%
import pandas as pd
df1 = pd.read_csv('parkinsons.data', sep=',') 
df1
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6    phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7    phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8    phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9    phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10   phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %%
df1.to_csv('parkinsons.txt', sep="\t")
